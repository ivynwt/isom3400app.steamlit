# %% [markdown]
# # <u>**Streamlit**</u>
#
# **Learning Objectives:**
# - Understand the difference between Streamlit and traditional web frameworks.
# - Build interactive UIs using widgets.
# - Visualize data dynamically.
# - Deploy an app to the cloud via GitHub.

# %% [markdown]
# ## **Environment Setup**
# Run the cell below in your virtual environment to install the necessary packages.

# %%
# Run this cell to install dependencies
pip install streamlit pandas numpy matplotlib

# %% [markdown]
# ---
# # **Streamlit Fundamentals**
#
# ## **1.1 What is Streamlit?**
# Streamlit is an open-source Python library that allows you to turn Python scripts into interactive web applications **without any knowledge of HTML, CSS, or JavaScript**.
#
# **Comparison:**
# - **Flask/Django:** You manage routes, templates, and front-end separately.
# - **Streamlit:** You write a Python script from top to bottom, and Streamlit handles the UI.
#
# ## **1.2 Your First App: `app.py`**
# Create a new file named `app.py` in the same directory as this notebook. Paste the code below into that file.

# %%
# ⚠️ This is NOT runnable in the notebook. 
# Copy this into a file named 'app.py' and run: streamlit run app.py
import streamlit as st

st.set_page_config(page_title = "My First App")

st.title("Streamlit Demo App")
st.header("User Input Section")

st.write("Please provide your details below:")

age = st.number_input("Enter your age:", min_value = 0, max_value = 120, value = 25)
color = st.selectbox("Choose your favorite color:", ["Red", "Blue", "Green"])

if st.button("Submit"):
    st.success(f"Thank you! Age: {age}, Favorite Color: {color}")

# %% [markdown]
# ### **How to Run the App**
# In your terminal (or a new cell in Jupyter), run:
# ```bash
# streamlit run app.py
# ```

# %% [markdown]
# ## **Task 1**
# **Task:** Modify the app to include a new widget that lets the user enter their **Name**. Display the Name in the greeting message inside the button.

# %%
# Write your code below

# %% [markdown]
# ---
# # **Charts, Data, and Deployment**
#
# ## **2.1 Working with Real Data & Charts**
# Let's create a new file: `dashboard.py`. This will be a more complex dashboard.
#
# We will:
# 1. Load a dataset (we'll generate one).
# 2. Add interactive filters.
# 3. Show both Matplotlib and Plotly charts.

# %%
# ⚠️ Copy this into a file named 'dashboard.py'

import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# -------------------------------
# Title and Description
# -------------------------------
st.title("Business Sales Dashboard")
st.write("Analyse monthly sales data interactively!")

# -------------------------------
# Sample Data
# -------------------------------
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
sales = np.random.randint(5000, 20000, size = 12)
expenses = np.random.randint(3000, 15000, size = 12)

data = pd.DataFrame({
    "Month": months,
    "Sales": sales,
    "Expenses": expenses
})

# -------------------------------
# Sidebar Filters
# -------------------------------
st.sidebar.header("Filters")
selected_months = st.sidebar.multiselect("Select Months", months, default = months)
show_expenses = st.sidebar.checkbox("Show Expenses", value = True)

# Filter data
filtered_data = data[data["Month"].isin(selected_months)]

# -------------------------------
# Display Data Table
# -------------------------------
st.subheader("Filtered Data")
st.dataframe(filtered_data)

# -------------------------------
# Interactive Chart
# -------------------------------
st.subheader("Sales Chart")
fig, ax = plt.subplots()
ax.plot(filtered_data["Month"], filtered_data["Sales"], marker = 'o', label = "Sales")
if show_expenses:
    ax.plot(filtered_data["Month"], filtered_data["Expenses"], marker = 'o', label = "Expenses")
ax.set_title("Monthly Performance")
ax.set_xlabel("Month")
ax.set_ylabel("Amount ($)")
ax.legend()
st.pyplot(fig)

# -------------------------------
# KPI Metrics
# -------------------------------
st.subheader("Key Metrics")
col1, col2, col3 = st.columns(3)
col1.metric("Total Sales", f"${filtered_data['Sales'].sum():,.0f}")
col2.metric("Total Expenses", f"${filtered_data['Expenses'].sum():,.0f}")
col3.metric("Profit", f"${(filtered_data['Sales'].sum() - filtered_data['Expenses'].sum()):,.0f}")

# %% [markdown]
# ## **2.2 Deploying to the Cloud via GitHub (Streamlit Community Cloud)**
#
# Streamlit offers **free** hosting if your code is on GitHub. Let's deploy `dashboard.py`.
#
# ### Step-by-Step Deployment Checklist
#
# 1.  **Create a GitHub Repository**
#     - Go to `github.com` -> New Repository.
#     - Name it `isom3400streamlit (or whatever you want)`.
#
# 2.  **Prepare Your Files**
#     You need **3 files** in your repository root:
#
#     **A. `dashboard.py`**.
#
#     **B. `requirements.txt`**
#     Create this file and paste the following:
#     ```text
#     streamlit
#     pandas
#     numpy
#     matplotlib
#     ```
#
#     **C. `README.md`** (Optional but good for documentation).
#
# 3.  **Push to GitHub**
#
# 4.  **Deploy on Streamlit Cloud**
#     - Visit: `https://share.streamlit.io`
#     - Click **"New app"**.
#     - Select your Repository, Branch (main), and Main file path (`dashboard.py`).
#     - Click **Deploy!**
#
# 5.  **Sharing the URL**
#     - Once built, you'll get a URL like `https://your-app-name.streamlit.app`.

# %% [markdown]
# ## **Task 2**
# **Task: Deploy a Personalized Streamlit App**
#
# 1.  **Modify `dashboard.py`** to change the title to include **your name** (e.g., `Alex's Sales Dashboard`).
# 2.  **Push** the change to **GitHub**.
# 3.  **Observe** the app automatically rebuild on Streamlit Cloud (it detects the Git push!).

# %%
# Write your code below

# %% [markdown]
# ## <u>**Exercise**</u>
# **Task: Create your own App**
#
# Build a Contact Info Collector using `st.form`.
#
# Specifications:
#
# - Use `st.form(key = "my_form")` as a context manager (visit https://docs.streamlit.io/ to see how to use `st.form()`).
#
# - Inside the form, collect:
#
#     - First Name (`st.text_input`)
#
#     - Last Name (`st.text_input`)
#
#     - Favourite Number (`st.number_input`)
#
# - Use `st.form_submit_button("Register")`.
#
# - Validation: When clicked, check if First Name and Last Name are not empty strings.
#
# - Output: If valid, write the data to a file called `contacts.csv` (append mode). Display `st.success`.
#
# - Display: Show the `contacts.csv` contents as a table below the form.

# %%
# Write your code below

# %% [markdown]
# ## **Extenstions**
# - **Session State:** Implement a counter button that remembers how many times it was clicked even after the script reruns (`st.session_state`).
# - **File Uploader:** Add `st.file_uploader` to allow users to upload their own CSV instead of using the dummy data.
# - **AI Integration:** Add `st.chat_input` and connect to an LLM (requires OpenAI/Anthropic API key).
